# %%
import numpy as np
import networkx as nx
import scipy.linalg as la
from matplotlib import pyplot as plt
import fun as f
import random, time, math, json
from collections import Counter
from SGD import SGD

# %%
WS_models_k = nx.read_gpickle("00-Graphs/171120WS-Graphs-fixed-p-05.json")

# %%
k0_list = list(WS_models_k['G_k0'].keys())

# %%
k0 = k0_list[0]
exp_unnormL = SGD(ref = k0, 
                  solve = "standard", 
                  G_ref = WS_models_k['G_k0'][k0],
                  G = WS_models_k['G_k'])

# %%
exp_unnormL.eigenspectrum_G_ref()
# Out:
# Eigen-decomposition of reference model with ref param : 10 completed.

# %%
exp_unnormL.eigenspectrum_G()
# Out:
# Eigen-decomposition of the 1450 models completed.
# took 78.49 minutes.

# %%
exp_unnormL.fit_SGD()
# Out:
# The spectral distance between G(10) and G(~) is an average  of the SGD between G(10) and the 50 replicate models for the 29 generations.
#
# d(G(10), G(10)): 0.0488289429066132, took: 0.5862 minutes
# d(G(10), G(20)): 0.04840697003947286, took: 0.5936 minutes
# d(G(10), G(30)): 0.048494204980869246, took: 0.5764 minutes
# d(G(10), G(40)): 0.048698056135414766, took: 0.5901 minutes
# d(G(10), G(50)): 0.04890226977605712, took: 0.5895 minutes
# d(G(10), G(60)): 0.04868723484198887, took: 0.5918 minutes
# d(G(10), G(70)): 0.048786453231733716, took: 0.6085 minutes
# d(G(10), G(80)): 0.049025623007132806, took: 0.61 minutes
# d(G(10), G(90)): 0.04889898830625575, took: 0.594 minutes
# d(G(10), G(100)): 0.048377512468031104, took: 0.5827 minutes
# d(G(10), G(110)): 0.048478971056757476, took: 0.6116 minutes
# d(G(10), G(120)): 0.04830851477719838, took: 0.61 minutes
# d(G(10), G(130)): 0.04826775489759074, took: 0.601 minutes
# d(G(10), G(140)): 0.048417883611129635, took: 0.5968 minutes
# d(G(10), G(150)): 0.04872576268817856, took: 0.5922 minutes
# d(G(10), G(160)): 0.048555885014434044, took: 0.5899 minutes
# d(G(10), G(170)): 0.04850256777080907, took: 0.5796 minutes
# d(G(10), G(180)): 0.0485422144326244, took: 0.5755 minutes
# d(G(10), G(190)): 0.048383393307209636, took: 0.6136 minutes
# d(G(10), G(200)): 0.04918401320290409, took: 0.6056 minutes
# d(G(10), G(210)): 0.04885862534928407, took: 0.6072 minutes
# d(G(10), G(220)): 0.04910176346944671, took: 0.6329 minutes
# d(G(10), G(230)): 0.04989574624872505, took: 0.6406 minutes
# d(G(10), G(240)): 0.04966472034085959, took: 0.6224 minutes
# d(G(10), G(250)): 0.04987780095902558, took: 0.6171 minutes
# d(G(10), G(260)): 0.050177203626018525, took: 0.6259 minutes
# d(G(10), G(270)): 0.05103605710664461, took: 0.6206 minutes
# d(G(10), G(280)): 0.05090611539536398, took: 0.6169 minutes
# d(G(10), G(290)): 0.0547051298102167, took: 0.6336 minutes
#
# Process took 17.51569971640905 minutes with an average of 0.6039841464196128 per generation

# %%
exp_sgd_dic = {}
exp_sgd_dic[k0] = exp_unnormL.rep_sgd

# %%
new_ref = k0_list[1]

exp_unnormL.reset_G_ref(new_ref, WS_models_k['G_k0'][new_ref])
exp_unnormL.eigenspectrum_G_ref()
# Out:
# Eigen-decomposition of reference model with ref param : 40 completed.

# %%
exp_unnormL.fit_SGD()
# Out:
# The spectral distance between G(40) and G(~) is an average  of the SGD between G(40) and the 50 replicate models for the 29 generations.
#
# d(G(40), G(10)): 0.04585182115624793, took: 0.5849 minutes
# d(G(40), G(20)): 0.04418874829130437, took: 0.5944 minutes
# d(G(40), G(30)): 0.04342813976822659, took: 0.5896 minutes
# d(G(40), G(40)): 0.043043078412480715, took: 0.616 minutes
# d(G(40), G(50)): 0.04340159267683868, took: 0.6165 minutes
# d(G(40), G(60)): 0.04335761710670028, took: 0.5966 minutes
# d(G(40), G(70)): 0.04342266969458711, took: 0.5847 minutes
# d(G(40), G(80)): 0.04374002378815671, took: 0.5844 minutes
# d(G(40), G(90)): 0.04330487498221574, took: 0.5881 minutes
# d(G(40), G(100)): 0.04379769289339669, took: 0.6178 minutes
# d(G(40), G(110)): 0.04426208766168962, took: 0.6435 minutes
# d(G(40), G(120)): 0.044252083923049426, took: 0.6467 minutes
# d(G(40), G(130)): 0.04440302162842629, took: 0.6335 minutes
# d(G(40), G(140)): 0.04452006608029516, took: 0.587 minutes
# d(G(40), G(150)): 0.04460487518421446, took: 0.5852 minutes
# d(G(40), G(160)): 0.0448532968335323, took: 0.5855 minutes
# d(G(40), G(170)): 0.0447533904825074, took: 0.5863 minutes
# d(G(40), G(180)): 0.04547647509773977, took: 0.5764 minutes
# d(G(40), G(190)): 0.04547228915519067, took: 0.5992 minutes
# d(G(40), G(200)): 0.0456019421142577, took: 0.6135 minutes
# d(G(40), G(210)): 0.04599718013915056, took: 0.6575 minutes
# d(G(40), G(220)): 0.04603709969747085, took: 0.6878 minutes
# d(G(40), G(230)): 0.0466566295536837, took: 0.5985 minutes
# d(G(40), G(240)): 0.04639730707765912, took: 0.5876 minutes
# d(G(40), G(250)): 0.04683846927364636, took: 0.6239 minutes
# d(G(40), G(260)): 0.04762710633478339, took: 0.5903 minutes
# d(G(40), G(270)): 0.0472512054557617, took: 0.5939 minutes
# d(G(40), G(280)): 0.047526266093902064, took: 0.5953 minutes
# d(G(40), G(290)): 0.053159569183402054, took: 0.5843 minutes
#
# Process took 17.549162395795186 minutes with an average of 0.6051393828172793 per generation

# %%
exp_sgd_dic[new_ref] = exp_unnormL.rep_sgd

# %%
new_ref = k0_list[2]
exp_unnormL.reset_G_ref(new_ref, WS_models_k['G_k0'][new_ref])
exp_unnormL.eigenspectrum_G_ref()
# Out:
# Eigen-decomposition of reference model with ref param : 70 completed.

# %%
exp_unnormL.fit_SGD()
# Out:
# The spectral distance between G(70) and G(~) is an average  of the SGD between G(70) and the 50 replicate models for the 29 generations.
#
# d(G(70), G(10)): 0.04866008992199979, took: 0.5987 minutes
# d(G(70), G(20)): 0.047206472589236756, took: 0.5844 minutes
# d(G(70), G(30)): 0.0465515772184174, took: 0.5954 minutes
# d(G(70), G(40)): 0.04609187248289416, took: 0.5874 minutes
# d(G(70), G(50)): 0.04604597456177312, took: 0.5777 minutes
# d(G(70), G(60)): 0.04547642074322658, took: 0.5936 minutes
# d(G(70), G(70)): 0.04488775073058162, took: 0.6014 minutes
# d(G(70), G(80)): 0.04540826160808403, took: 0.5875 minutes
# d(G(70), G(90)): 0.045619898341451165, took: 0.582 minutes
# d(G(70), G(100)): 0.046035555007597956, took: 0.5852 minutes
# d(G(70), G(110)): 0.04620911229480229, took: 0.5786 minutes
# d(G(70), G(120)): 0.04681666516463544, took: 0.5884 minutes
# d(G(70), G(130)): 0.04640888754330926, took: 0.5902 minutes
# d(G(70), G(140)): 0.046605395536228264, took: 0.5854 minutes
# d(G(70), G(150)): 0.04660457541239707, took: 0.6009 minutes
# d(G(70), G(160)): 0.04689993529949717, took: 0.5892 minutes
# d(G(70), G(170)): 0.047415478369613344, took: 0.5848 minutes
# d(G(160), G(150)): 0.046490733101474196, took: 0.5823 minutes
# d(G(160), G(160)): 0.04645269356712028, took: 0.5889 minutes
# d(G(160), G(170)): 0.046272692779945876, took: 0.5854 minutes
# d(G(160), G(180)): 0.04672522545384195, took: 0.5899 minutes
# d(G(160), G(190)): 0.04684442401702861, took: 0.5937 minutes
# d(G(160), G(200)): 0.04738666363517751, took: 0.5902 minutes
# d(G(160), G(210)): 0.0471859461994145, took: 0.5808 minutes
# d(G(160), G(220)): 0.04770437636177247, took: 0.5918 minutes
# d(G(160), G(230)): 0.047715070771459714, took: 0.5763 minutes
# d(G(160), G(240)): 0.04760662252578147, took: 0.5827 minutes
# d(G(160), G(250)): 0.047825862778820595, took: 0.5888 minutes
# d(G(160), G(260)): 0.048273030254400086, took: 0.6052 minutes
# d(G(160), G(270)): 0.048492873124900894, took: 0.5847 minutes
# d(G(160), G(280)): 0.048761046246042675, took: 0.5897 minutes
# d(G(160), G(290)): 0.053299105733265024, took: 0.5864 minutes
#
# Process took 17.14572354952494 minutes with an average of 0.5912284592102314 per generation

# %%
exp_sgd_dic[new_ref] = exp_unnormL.rep_sgd

# %%
new_ref = k0_list[6]
exp_unnormL.reset_G_ref(new_ref, WS_models_k['G_k0'][new_ref])
exp_unnormL.eigenspectrum_G_ref()
# Out:
# Eigen-decomposition of reference model with ref param : 190 completed.

# %%
exp_unnormL.fit_SGD()
# Out:
# The spectral distance between G(190) and G(~) is an average  of the SGD between G(190) and the 50 replicate models for the 29 generations.
#
# d(G(190), G(10)): 0.0462921828789043, took: 0.6244 minutes
# d(G(190), G(20)): 0.04625458971452957, took: 0.5984 minutes
# d(G(190), G(30)): 0.046133245856478614, took: 0.6046 minutes
# d(G(190), G(40)): 0.04565424720206347, took: 0.6208 minutes
# d(G(190), G(50)): 0.0459136053250945, took: 0.5866 minutes
# d(G(190), G(60)): 0.04584039900087231, took: 0.5921 minutes
# d(G(190), G(70)): 0.04576242413391676, took: 0.5998 minutes
# d(G(190), G(80)): 0.04584513545742833, took: 0.5906 minutes
# d(G(190), G(90)): 0.045011615553670836, took: 0.6088 minutes
# d(G(190), G(100)): 0.04511845255202157, took: 0.5809 minutes
# d(G(190), G(110)): 0.045139451142766955, took: 0.5754 minutes
# d(G(190), G(120)): 0.04545347869449716, took: 0.5819 minutes
# d(G(190), G(130)): 0.045465663268846095, took: 0.5809 minutes
# d(G(190), G(140)): 0.04512556417761461, took: 0.5864 minutes
# d(G(190), G(150)): 0.04532911812096522, took: 0.6001 minutes
# d(G(190), G(160)): 0.04499287430375018, took: 0.584 minutes
# d(G(190), G(170)): 0.04500676019826314, took: 0.5919 minutes
# d(G(190), G(180)): 0.04482886882962482, took: 0.5955 minutes
# d(G(190), G(190)): 0.044759236223433634, took: 0.6029 minutes
# d(G(190), G(200)): 0.04502481090287293, took: 0.599 minutes
# d(G(190), G(210)): 0.04524330461105596, took: 0.5893 minutes
# d(G(190), G(220)): 0.045218960760112135, took: 0.6501 minutes
# d(G(190), G(230)): 0.045401592837427535, took: 0.6332 minutes
# d(G(190), G(240)): 0.045040973958035656, took: 0.6251 minutes
# d(G(190), G(250)): 0.0457944707950782, took: 0.615 minutes
# d(G(190), G(260)): 0.04682865110394949, took: 0.5866 minutes
# d(G(190), G(270)): 0.04694130406451086, took: 0.5837 minutes
# d(G(190), G(280)): 0.04696467116045218, took: 0.578 minutes
# d(G(190), G(290)): 0.051640272118751974, took: 0.6064 minutes
#
# Process took 17.372555685043334 minutes with an average of 0.5990502578088607 per generation

# %%
exp_sgd_dic[new_ref] = exp_unnormL.rep_sgd

# %%
new_ref = k0_list[7]
exp_unnormL.reset_G_ref(new_ref, WS_models_k['G_k0'][new_ref])
exp_unnormL.eigenspectrum_G_ref()
# Out:
# Eigen-decomposition of reference model with ref param : 220 completed.

# %%
exp_unnormL.fit_SGD()
# Out:
# The spectral distance between G(220) and G(~) is an average  of the SGD between G(220) and the 50 replicate models for the 29 generations.
#
# d(G(220), G(10)): 0.04853377925451138, took: 0.6311 minutes
# d(G(220), G(20)): 0.04830760308113953, took: 0.6269 minutes
# d(G(220), G(30)): 0.04782020747662137, took: 0.6067 minutes
# d(G(220), G(40)): 0.04821074093830749, took: 0.6215 minutes
# d(G(220), G(50)): 0.048092126534437965, took: 0.6381 minutes
# d(G(220), G(60)): 0.047892800267910124, took: 0.7122 minutes
# d(G(220), G(70)): 0.0477848956094886, took: 0.6986 minutes
# d(G(220), G(80)): 0.04783819676634476, took: 0.6968 minutes
# d(G(220), G(90)): 0.047278366773004406, took: 0.6207 minutes
# d(G(220), G(100)): 0.04714635298793333, took: 0.5926 minutes
# d(G(220), G(110)): 0.04711799257877458, took: 0.5908 minutes
# d(G(220), G(120)): 0.047231004174256457, took: 0.582 minutes
# d(G(220), G(130)): 0.04693795148096314, took: 0.5941 minutes
# d(G(220), G(140)): 0.04663454217725902, took: 0.5849 minutes
# d(G(220), G(150)): 0.04667511768296905, took: 0.593 minutes
# d(G(220), G(160)): 0.0463321029213358, took: 0.6053 minutes
# d(G(220), G(170)): 0.04730588748749872, took: 0.5989 minutes
# d(G(220), G(180)): 0.04660592226725498, took: 0.6275 minutes
# d(G(220), G(190)): 0.04647632789510973, took: 0.6115 minutes
# d(G(220), G(200)): 0.04617773528000306, took: 0.5889 minutes
# d(G(220), G(210)): 0.04666399703418143, took: 0.5862 minutes
# d(G(220), G(220)): 0.04687538549067102, took: 0.5855 minutes
# d(G(220), G(230)): 0.04680626264903716, took: 0.5766 minutes
# d(G(220), G(240)): 0.046936176547859663, took: 0.5731 minutes
# d(G(220), G(250)): 0.04731717971654366, took: 0.5789 minutes
# d(G(220), G(260)): 0.04826465835858837, took: 0.5751 minutes
# d(G(220), G(270)): 0.04831903060391506, took: 0.5757 minutes
# d(G(220), G(280)): 0.04801438989312235, took: 0.5963 minutes
# d(G(220), G(290)): 0.05124151552557175, took: 0.6174 minutes
#
# Process took 17.687351500988008 minutes with an average of 0.6099007877810249 per generation

# %%
exp_sgd_dic[new_ref] = exp_unnormL.rep_sgd

# %%
new_ref = k0_list[8]
exp_unnormL.reset_G_ref(new_ref, WS_models_k['G_k0'][new_ref])
exp_unnormL.eigenspectrum_G_ref()
# Out:
# Eigen-decomposition of reference model with ref param : 250 completed.

# %%
exp_unnormL.fit_SGD()
# Out:
# The spectral distance between G(250) and G(~) is an average  of the SGD between G(250) and the 50 replicate models for the 29 generations.
#
# d(G(250), G(10)): 0.05105358651463274, took: 0.6407 minutes
# d(G(250), G(20)): 0.05120989149550114, took: 0.6156 minutes
# d(G(250), G(30)): 0.05067020136067896, took: 0.6072 minutes
# d(G(250), G(40)): 0.05097843791859108, took: 0.5878 minutes
# d(G(250), G(50)): 0.051013356512999763, took: 0.5841 minutes
# d(G(250), G(60)): 0.05108270939021804, took: 0.6246 minutes
# d(G(250), G(70)): 0.050875011446984836, took: 0.641 minutes
# d(G(250), G(80)): 0.050958384697677835, took: 0.6031 minutes
# d(G(250), G(90)): 0.05074880621410488, took: 0.6229 minutes
# d(G(250), G(100)): 0.05027168598692953, took: 0.6274 minutes
# d(G(250), G(110)): 0.050274231063275165, took: 0.5853 minutes
# d(G(250), G(120)): 0.049721674903478785, took: 0.5867 minutes
# d(G(250), G(130)): 0.049631175520110545, took: 0.5717 minutes
# d(G(250), G(140)): 0.049644545767391524, took: 0.5863 minutes
# d(G(250), G(150)): 0.04956025568171858, took: 0.5721 minutes
# d(G(250), G(160)): 0.04955528807034077, took: 0.5688 minutes
# d(G(250), G(170)): 0.04936278648774065, took: 0.5797 minutes
# d(G(250), G(180)): 0.04899015837867632, took: 0.5744 minutes
# d(G(250), G(190)): 0.04900678112771482, took: 0.5736 minutes
# d(G(250), G(200)): 0.04874281578807356, took: 0.5679 minutes
# d(G(250), G(210)): 0.048766136008111395, took: 0.5696 minutes
# d(G(250), G(220)): 0.048383080197010014, took: 0.5737 minutes
# d(G(250), G(230)): 0.04866005197805257, took: 0.5748 minutes
# d(G(250), G(240)): 0.049016334680841336, took: 0.5711 minutes
# d(G(250), G(250)): 0.04890629410300515, took: 0.5721 minutes
# d(G(250), G(260)): 0.04941698666586336, took: 0.5723 minutes
# d(G(250), G(270)): 0.04954236165075888, took: 0.5714 minutes
# d(G(250), G(280)): 0.04952838054586712, took: 0.5675 minutes
# d(G(250), G(290)): 0.05191913187970518, took: 0.5895 minutes
#
# Process took 17.083002750078837 minutes with an average of 0.5890655259976443 per generation

# %%
exp_sgd_dic[new_ref] = exp_unnormL.rep_sgd

# %%
new_ref = k0_list[9]
exp_unnormL.reset_G_ref(new_ref, WS_models_k['G_k0'][new_ref])
exp_unnormL.eigenspectrum_G_ref()
# Out:
# Eigen-decomposition of reference model with ref param : 280 completed.

# %%
exp_unnormL.fit_SGD()
# Out:
# The spectral distance between G(280) and G(~) is an average  of the SGD between G(280) and the 50 replicate models for the 29 generations.
#
# d(G(280), G(10)): 0.049386311116536616, took: 0.5859 minutes
# d(G(280), G(20)): 0.04932960423842234, took: 0.59 minutes
# d(G(280), G(30)): 0.04909040560756413, took: 0.5781 minutes
# d(G(280), G(40)): 0.04881264197445225, took: 0.5826 minutes
# d(G(280), G(50)): 0.048910186640770265, took: 0.5868 minutes
# d(G(280), G(60)): 0.04859670940894068, took: 0.582 minutes
# d(G(280), G(70)): 0.048157703276631464, took: 0.578 minutes
# d(G(280), G(80)): 0.04819264455633747, took: 0.5883 minutes
# d(G(280), G(90)): 0.04782634607665049, took: 0.5716 minutes
# d(G(280), G(100)): 0.047639301546161396, took: 0.5861 minutes
# d(G(280), G(110)): 0.047552074621419235, took: 0.5713 minutes
# d(G(280), G(120)): 0.04754073051220058, took: 0.6263 minutes
# d(G(280), G(130)): 0.04718588134384857, took: 0.7909 minutes
# d(G(280), G(140)): 0.046949546952488944, took: 0.6781 minutes
# d(G(280), G(150)): 0.04739675427915758, took: 0.6294 minutes
# d(G(280), G(160)): 0.047020426664005646, took: 0.6963 minutes
# d(G(280), G(170)): 0.047051148477331974, took: 0.692 minutes
# d(G(280), G(180)): 0.04769512468307165, took: 0.6077 minutes
# d(G(280), G(190)): 0.047717117969193715, took: 0.5886 minutes
# d(G(280), G(200)): 0.04769629530267345, took: 0.5565 minutes
# d(G(280), G(210)): 0.048045249499580917, took: 0.5503 minutes
# d(G(280), G(220)): 0.04828821468777403, took: 0.6451 minutes
# d(G(280), G(230)): 0.047914394102375545, took: 0.6098 minutes
# d(G(280), G(240)): 0.04811893305318757, took: 0.614 minutes
# d(G(280), G(250)): 0.04802246629251267, took: 0.5998 minutes
# d(G(280), G(260)): 0.047981205776680656, took: 0.5995 minutes
# d(G(280), G(270)): 0.04800402507423297, took: 0.5947 minutes
# d(G(280), G(280)): 0.04779305064363796, took: 0.5983 minutes
# d(G(280), G(290)): 0.052006248706944556, took: 0.5989 minutes
#
# Process took 17.676957352956137 minutes with an average of 0.6095459714703175 per generation

# %%
exp_sgd_dic[new_ref] = exp_unnormL.rep_sgd

# %%
mean_dic = {}
std_dic = {}
A_dic_ref = {}
for key, value in exp_sgd_dic.items():
    A_dic_ref[key] = (nx.adjacency_matrix(WS_models_k['G_k0'][key])).todense()
    mean_dic[key] = [np.mean(value[i]) for i in exp_unnormL.keys]
    std_dic[key] = [np.std(value[i]) for i in exp_unnormL.keys]

# %%
Hamming_dist_dic = {}
Hamming_dist_avg_dic = {}
for key, A_p0 in A_dic_ref.items():
    Hamming_dist_dic[key] = f.hamming_dist_models(A_p0, exp_unnormL.A_dic_G, 50)
    Hamming_dist_avg_dic[key] = [np.mean(Hamming_dist_dic[key][k]) for k in exp_unnormL.keys]

# %%
Results171120 = {}
Results171120['mean_dist'] = mean_dic
Results171120['std_dist'] = std_dic
Results171120['hamming_dist'] = Hamming_dist_dic
Results171120['hamming_dist_avg'] = Hamming_dist_avg_dic
np.save('02-Results/171120Results-fixedp05.npy', Results171120)

# %% [markdown]
# ## Spectral Graph Distance

# %%
k0_list = list(exp_sgd_dic.keys())
k_list = list(exp_sgd_dic[k0_list[0]].keys())
fig = plt.figure(figsize=(13, 9))
for i in range(10):
    k0 = k0_list[i]
    plt.subplot(4, 3, i+1)
    plt.tight_layout()
    plt.title(r'$k_0$ = ' + str(k0))
    plt.xlabel('k')
    plt.ylabel('Spectral graph distance.')
    plt.plot(exp_unnormL.keys, mean_dic[k0], '-o', color = 'red')
    plt.plot(k_list[np.argmin(mean_dic[k0])], np.min(mean_dic[k0]), 'x', color = 'blue')
    plt.axvline(x = k0, color = 'blue', linestyle = '--', label = "k_0 = "+ str(k0))
    plt.fill_between(exp_unnormL.keys, [mean_dic[k0][i] - std_dic[k0][i] for i in range(len(mean_dic[k0]))],
                     [mean_dic[k0][i] + std_dic[k0][i] for i in range(len(std_dic[k0]))], 
                     color = 'lightgrey')

# %% [markdown]
# ## Hamming Distance

# %%
p0_list = list(exp_sgd_dic.keys())
p0=p0_list[0]
fig = plt.figure(figsize=(12, 8))
for i in range(10):
    p0=p0_list[i]
    plt.subplot(4, 3, i+1)
    plt.tight_layout()
    plt.title('p_0 = ' + str(p0))
    plt.xlabel('p')
    plt.ylabel('SGD')
    plt.axvline(x = p0, color = 'blue', linestyle = '--', label = "p_0 = "+ str(p0))
    plt.plot(exp_unnormL.keys, Hamming_dist_avg_dic[p0], '-o', color = 'red')

# %%
# np.save('my_file.npy', exp_sgd_dic) 
#np.save('17112020eigenv.npy', exp_unnormL.sort_eigenv_dic)
